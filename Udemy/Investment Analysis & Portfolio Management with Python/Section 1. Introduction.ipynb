# %% [markdown]
# # IMPORTANT: Pre-Requisites | Please read before enrolling.
# We really want to make sure this is clear, so that the expectations of the course are clear, and so you can get the best learning experience.
#
# This is a Finance course - not a Python course.
#
# **That means we've designed this course assuming you know how to code.**
#
# You don't need to be an 'expert' in Python, but...
#
# **/!\ WE ASSUME YOU KNOW:**
#
# - The difference between:
#     - "strings", "integers", "floats", and "booleans".
#     - "lists", "tuples", and "dictionaries".
# - How to write "if else" statements.
# - How to "slice" and "concatenate" lists.
#
#
#
# In this course, we use Python as a tool to conduct investment analysis and portfolio management.
#
#
#
# The emphasis of the course is on Finance.
#
# We dive deep into the equations of Investment Analysis & Portfolio Management. We rip apart each equation one variable at a time, and explain the intuition and rationale behind each and every formula, from scratch.
#
# You'll calculate and work with equations manually first, and only then move on to implementing it on Python.
#
# ### THIS COURSE IS NOT FOR YOU IF...
#
# - You want to learn Python from scratch.
# - You want to learn Python for Finance from scratch.
# - You want to learn about data structures and algorithms.
# - You want to learn about how Python works behind the scenes (e.g. how Python manages memory).
#
# ### THIS COURSE IS FOR YOU IF...
#
# - You want to learn Investment Analysis & Portfolio Management using Python.
# - You want to learn how to quantify and measure the return and risk of individual stocks.
# - You want to learn how to quantify and measure portfolio returns and risk.
# - You want to learn how to use Python to optimise portfolio returns and risk, minimise portfolio risk, maximise expected returns.

# %% [markdown]
# # Course FAQs
# We love questions that push the intellectual boundaries. Questions that change the way we think. And those that help us reach new heights.
#
# Those questions, we encourage you to ask.
#
# Some questions are very basic and common however, and answering these places a great burden on the limited resources Fervent has.
#
# Please read these FAQs before proceeding to take the course.
#
# ### Credentials and relevance related questions
# - **Who teaches this course?**
#     - The course is designed and delivered by Vash, who holds an MPhil (Scholar) (WBS) in Finance and Econometrics, MSc (Scholar) (Exon) in Finance and Accounting, and BSc (BA, per tradition) (Hons) (Exon) in Business and Accounting from Russell Group Universities (Warwick & Exeter, UK).
#     - He has over 9 years of professional training and teaching experience, with clients including Associates at Big 4 Accounting / Audit firms, Finance Directors at SMEs, as well as University / College students at the Undergraduate, Postgraduate, and MBA levels. Vash has a track record of consistently delivering student-centric content and simplifying complex concepts in an engaging and constructive manner.
#     - His current research involves assessing the impact of trust on market pricing, working with a rich set of 'Big Data' and applying a variety of methodologies including (but not limited to) applications of Natural Language Processing (NLP) in both supervised and unsupervised machine learning, factor modelling, and event studies.
#
#
#
# - **Is the course relevant for my University / College course on Finance?**
#     - The Finance related course content is relevant for most Ivy League / Russell Group Universities. You should check your module handbook (aka course handbook, module outline, course outline) to make sure.
#
#
#
# ### Questions relating to Pre-requisites
# - **Do I need to know how to code?**
#     - Yes, coding knowledge is required and assumed, but you do not need to be an expert in Python to take the course.
#     - Even though we explain each line of code step by step, the course is designed on the assumption that you know how to code.
#     - Specifically, at a minimum, we assume you know the difference between lists, tuples, and dictionaries in terms of data structures. We also assume you know the difference between strings, integers, and floats.
#
#
#
# - **I don't know how to code, but still want to learn Investment Analysis & Portfolio Management - can I achieve that in this course?**
#     - If you don't know how to code, but still want to learn Investment Analysis & Portfolio Management, we recommend enrolling on our sister course, "Investment Analysis & Portfolio Management - Core Finance". That course teaches the same concepts, albeit on Excel® and Google Sheets instead of Python.
#
#
#
# - **Will you teach me how to setup Python?**
#     - No, because we assume you already have it setup, since we assume you know how to code.
#
#
#
# - **Can you recommend a Python course so I can learn to code?**
#     - Unfortunately, no. Fervent cannot verify nor vouch for courses where we do not control the learning experience design and delivery end-to-end.
#     - Fervent has great respect for Corey Schafer and Sentdex who both provide credible, valuable content on YouTube for aspiring programmers.
#
#
#
# - **Do I need to know Financial concepts or Statistics?**
#     - No. Knowledge of Finance is not required. Knowledge of statistics is useful but not essential.
#
#
#
# ### Questions relating to support
# - **My code throws an error, even though I've done exactly what's shown in the video.**
#     - Please use the code provided in the Resources folder, and compare the results. Oftentimes, it can look like your code is identical, but there might be a very small, hard to notice syntax error which can cause an error.
#
#
#
# - **I'm having technical issues with video or sound, who do I contact?**
#     - Please contact Udemy directly via support@udemy.com as this is something only they can help with.
#
#
#
# - **How do I get my certificate of completion?**
#     - Please see instructions from Udemy here: https://support.udemy.com/hc/en-us/articles/229603868-Certificate-of-Completion
#
#
#
# - **I've completed the course, but it still says I haven't finished it.**
#     -Please contact Udemy directly via support@udemy.com along with screenshots of your progress, as this is something only they can help with.
#
#
# - **Do you provide personal or corporate training?**
#     - Yes. Please see our website for more information and get in touch with us directly.

# %% [markdown]
# # Accessing Financial Data
# - Access to financial data can be quite expensive. Fortunately, there are some free alternatives.
#
# ### Accessing Financial Data Manually
# - You can access data manually from Yahoo! Finance here: http://finance.yahoo.com
# - Alternatively, you can access it from Google Finance by opening a Google Sheets document at http://sheets.google.com/ and using the "GOOGLEFINANCE" function.
#
#
#
# ### Accessing Financial Data Programatically
# Pandas Datareader
#
# - Accessing data via Python's Pandas Datareader has known issues and is not very reliable at this point in time. That is why we do not use it in the course.
#
# Other sources
#
# - There are other reliable, and really useful sources of financial data available via API calls, such that the data can be loaded programatically into Python.
# - Unfortunately, we cannot mention those sources nor display them in the course due to copyright restrictions and ambiguity. We spoke with the API providers but did not get a clear, unambiguous response about whether or not we can display them in this course.
#
#
# ### Data in this course
# - All of the data in this course is obtained from Yahoo! Finance and / or Google Sheets.
# - Throughout the course, you'll have access to the datasets we use in the videos as csv files.
# - Note that in the real world, it is very uncommon for people to download data from Yahoo! Finance or Google Sheets when coding in Python.
#
# While we will give you data to work with in the course, we strongly recommend working with your own datasets. This will help you better apply what you learn, and also deal with data cleaning / "data wrangling" effectively.
#
#
#
# To find relevant APIs which we cannot name, search "financial and alternative data api python" on Google.
